# %%
import preprocessing as p
# Enable module reloading
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# in normal case use normalization=True, this example is only for demostrating purposes
a, labels = p.get_image_generator('../../data/train/relationships.csv', '../../data/imgs_numpy/',
                                  batch_size=10, normalize=False)

# %%
batch = next(a)

# %%
labels
# Out:
# {'/m/01mzpv': 0,
#  '/m/04yx4': 1,
#  '/m/04bcr3': 2,
#  '/m/03bt1vf': 3,
#  '/m/04dr76w': 4,
#  '/m/0342h': 5,
#  '/m/05r655': 6,
#  '/m/01y9k5': 7,
#  '/m/0cvnqh': 8,
#  '/m/080hkjn': 9}

# %%
batch
# Out:
# ([3, 3], [array([[[222, 222, 236],
#           [219, 222, 231],
#           [197, 199, 209],
#           ...,
#           [154, 165, 188],
#           [153, 163, 186],
#           [150, 160, 184]],
#
#          [[226, 226, 240],
#           [221, 223, 233],
#           [196, 198, 209],
#           ...,
#           [152, 161, 187],
#           [153, 162, 188],
#           [152, 161, 188]],
#
#          [[223, 223, 237],
#           [217, 220, 231],
#           [197, 201, 212],
#           ...,
#           [152, 160, 188],
#           [151, 160, 188],
#           [153, 161, 189]],
#
#          ...,
#
#          [[194, 197, 218],
#           [199, 200, 220],
#           [201, 202, 222],
#           ...,
#           [141, 148, 171],
#           [153, 159, 182],
#           [151, 157, 180]],
#
#          [[200, 203, 224],
#           [202, 203, 223],
#           [202, 203, 223],
#           ...,
#           [153, 160, 181],
#           [154, 160, 183],
#           [152, 158, 180]],
#
# ...

# %%
def imshow(img):
    import cv2
    import IPython
    _,ret = cv2.imencode('.jpg', img) 
    i = IPython.display.Image(data=ret)
    IPython.display.display(i)

# %%
print(labels, batch[0])
imshow(batch[1][0])
# Out:
# {'/m/01mzpv': 0, '/m/04yx4': 1, '/m/04bcr3': 2, '/m/03bt1vf': 3, '/m/04dr76w': 4, '/m/0342h': 5, '/m/05r655': 6, '/m/01y9k5': 7, '/m/0cvnqh': 8, '/m/080hkjn': 9} [3, 3]
